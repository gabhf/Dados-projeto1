# %% [markdown]
# # Projeto 1 - Ciência dos Dados

# %% [markdown]
# Nome: Gabriel Huerta Façanha

# %% [markdown]
# ## Pergunta (s) a ser respondida

# %% [markdown]
# O Banco Africano de Desenvolvimento (AfDB) contribuiu na infraestrutura(saúde e educação) de países africanos?

# %% [markdown]
# ## Explicação da hipótese e mecanismo

# %% [markdown]
# O AfDB é um fundo para o desenvolvimento da região africana que conta com ajuda de diversos países for do continente assim como países da África. O ponto é estudar se os investimentos desse fundo têm impacto no desenvolvimento da área. Para isso foram estudados alguns países beneficiados pelo bloco assim como países de fora dele para comparação.

# %% [markdown]
# ## Bases de dados usadas

# %% [markdown]
# os dados de mortalidade infantil e taxa de adultos com hiv foram tirados do banco de dados em https://www.gapminder.org/data/

# %% [markdown]
# ## Análise de dados

# %% [markdown]
# Insira abaixo uma análise de dados tratada para ter maior clareza.
#
# Lembre-se de que, além deste arquivo principal, você precisa entregar um ou mais *notebooks* mais brutos com todas as tentativas que fez e que não deram certo .
#
# **Não inclua dados ou gráficos sem motivação nem interpretação** - sempre que fizer uma análise, plot ou tablea, diga qual sua intenção. Logo após a apresentação diga qual conclusão específica ou interpretação você tira daquela análise

# %%
# %matplotlib inline

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\gabriel\Desktop\INSPER\Ciencia dos Dados\cd19\Projeto1

# %%
# mortalidade infantil por 1000 nascidos :
mi = pd.read_excel('child_mortality_0_5_year_olds_dying_per_1000_born.xlsx')
#mortalidade infantil como medidor para saúde e saneamento

#porcentagem de adultos (15 a 49) com hiv estimada:
hiv = pd.read_excel('newly_hiv_infected_percent_age_15_49.xlsx')
#taxa de adultos com HIV como medidor de saúde e educação

# %%
afdb = ['Angola','Gabon','Congo','Cameroon',"Cote d'Ivoire",'South Africa','Ghana','Ethiopia','Nigeria','Tunisia','India','Brazil']
sel_paises = mi.loc[mi['country'].isin(afdb)]
dados1 = sel_paises.set_index('country')
#dados1 se refere à primeira variável estudada (mortalidade infantil)
dados1
# Out:
#                 1800   1801   1802   1803   1804   1805   1806   1807   1808  \
# country
# Angola         486.0  486.0  486.0  486.0  486.0  486.0  486.0  486.0  486.0
# Brazil         417.0  417.0  417.0  417.0  417.0  417.0  417.0  417.0  417.0
# Cameroon       460.0  460.0  460.0  460.0  460.0  460.0  460.0  460.0  460.0
# Cote d'Ivoire  428.0  428.0  428.0  428.0  428.0  428.0  428.0  428.0  428.0
# Ethiopia       448.0  448.0  448.0  448.0  448.0  448.0  448.0  448.0  448.0
# Gabon          436.0  436.0  436.0  436.0  436.0  436.0  436.0  436.0  436.0
# Ghana          471.0  471.0  471.0  471.0  471.0  471.0  471.0  471.0  471.0
# India          509.0  509.0  509.0  509.0  509.0  509.0  509.0  509.0  509.0
# Nigeria        438.0  438.0  438.0  438.0  438.0  438.0  438.0  438.0  438.0
# South Africa   398.0  398.0  398.0  398.0  398.0  398.0  398.0  398.0  398.0
# Tunisia        460.0  460.0  460.0  460.0  460.0  460.0  460.0  460.0  460.0
#
# ...

# %%
sel_paises = hiv.loc[mi['country'].isin(afdb)]
dados2 = sel_paises.set_index('country')
#dados2 se refere à segunda variável estudada (taxa de adultos(15 a 49 anos) 
#porém não há dados suficientes para todos os países estudados)
dados2
# Out:
#                1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  \
# country
# Australia       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Canada          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Cote d'Ivoire  1.03  1.30  1.46  1.46  1.30  1.08  0.88  0.72  0.60  0.51
# Ethiopia       0.36  0.44  0.52  0.55  0.56  0.56  0.54  0.51  0.46  0.41
# Honduras        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Indonesia      0.06  0.06  0.06  0.06  0.06  0.06  0.06  0.06  0.06  0.06
# Italy           NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Lithuania      0.06  0.06  0.06  0.06  0.06  0.06  0.06  0.06  0.06  0.06
# Sweden          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                ...   2002  2003  2004  2005  2006  2007  2008  2009  2010  \
# country        ...
# Australia      ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
# os anos de 1996 e 2006 foram marcantes pois representaram, respectivamente o quase colapso e um sinal de recuperação do Banco

dados1_2008 = dados1.loc[:,[1992,1996,2000,2003,2006,2010,2014,2018]]
dados1_2008
# Out:
#                 1992   1996   2000   2003   2006   2010   2014  2018
# country
# Angola         223.0  222.0  207.0  186.0  158.0  119.0   91.2  81.6
# Brazil          58.4   46.0   35.8   29.6   24.5   19.8   16.4  14.2
# Cameroon       152.0  170.0  166.0  147.0  131.0  108.0   87.5  75.7
# Cote d'Ivoire  151.0  151.0  146.0  135.0  124.0  111.0   98.3  84.2
# Ethiopia       193.0  168.0  144.0  124.0  104.0   80.9   64.4  53.9
# Gabon           90.8   88.4   84.6   79.9   74.1   63.7   53.0  45.8
# Ghana          119.0  111.0  100.0   91.4   84.9   74.7   63.4  56.4
# India          119.0  106.0   91.5   81.0   71.2   58.8   47.7  41.1
# Nigeria        212.0  206.0  187.0  170.0  152.0  130.0  112.0  97.9
# South Africa    55.1   59.1   66.7   73.2   72.6   53.7   44.5  39.8
# Tunisia         52.3   42.0   31.7   26.0   21.7   17.4   14.6  12.6

# %% [markdown]
# ## Conclusão

# %% [markdown]
# Responda à pergunta, argumento da melhor forma possível com base nos dados

# %% [markdown]
#  Os dados coletados mostram que após a crise do bloco em 1996 e antes de 2006 a taxa de mortalidade infantil decresceu menos rapidamente se comparado aos anos após a recuperação do Banco em 2006.
#  Além disso de 1996 a 2006 os países de fora não sofreram esse efeito.
